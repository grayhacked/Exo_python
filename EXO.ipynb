# %%
"""
Enoncé : Ou gen yon adrès IP.

Ou dwe rantre nan yon pòt(PORT) ki ouvri. Ou pa gen anpil tan pou skane tout pòt yo, men ou konnen pòt ki ouvri a, li egal total tout dijit yo ki nan adrès IP a, miltiplye pa premye dijit ki nan adrès IP a.

Mande itilizatè a pou l tape adrès IP a, epi afiche pòt ki ouvri a

NB: Tout adrès ip separe ak pwen(.)

Egzanp: Si itilizatè a antre adrès IP
"127.0.0.1" ap bay rezilta
(1+2+7+0+0+1) * 1 = 11 =>
Donk pòt ki ouvri a se 11
"""
# Out:
# '\nEnoncé : Ou gen yon adrès IP.\n\nOu dwe rantre nan yon pòt(PORT) ki ouvri. Ou pa gen anpil tan pou skane tout pòt yo, men ou konnen pòt ki ouvri a, li egal total tout dijit yo ki nan adrès IP a, miltiplye pa premye dijit ki nan adrès IP a.\n\nMande itilizatè a pou l tape adrès IP a, epi afiche pòt ki ouvri a\n\nNB: Tout adrès ip separe ak pwen(.)\n\nEgzanp: Si itilizatè a antre adrès IP\n"127.0.0.1" ap bay rezilta\n(1+2+7+0+0+1) * 1 = 11 =>\nDonk pòt ki ouvri a se 11\n'

# %%
#fonction principale
def ip_to_sum(ip_address):
    digits = ip_address.split('.')
    valeur = list(digits[0]) + list(digits[1]) + list(digits[2]) + list(digits[3])
    first_digits = int(valeur[0])
    somme = 0
    for chiffre in valeur:
        somme += int(chiffre)
    return somme*first_digits

# %%
#demande a l'utilisateur de rentrer une adresse IP
IP = input("Enter IP address: ")
output = ip_to_sum(IP)
print("the available port is:", output)
# Out:
# the available port is: 11

# %%
"""
Ennoncé2 : Afiche OK si antye N a PA divizib pa 4, afichye NOK nan lòt ka
"""
# Out:
# '\nEnnoncé2 : Afiche OK si antye N a PA divizib pa 4, afichye NOK nan lòt ka\n'

# %%
def divisible_par_4(n):
    if n % 4 != 0:
        return "OK"
    else:
        return "NOK"

# %%
a = int(input("Antre yon antye N: "))
resultat = divisible_par_4(a)
print(resultat)
# Out:
# NOK

# %%
"""
Enoncé3 : Mande itilizate non l. Itilize pwòp teknik pa w pou mete non sa nan fòma tit. Sa vle di premye lèt chak mo dwe majiskil, epi lòt yo miniskil. Epi afiche nouvo non an.
Ekzanp:

Ayiti se yon BEL PEYI"  ap vin bay "Ayiti Se Yon Bel Peyi 
"""
# Out:
# '\nEnoncé3 : Mande itilizate non l. Itilize pwòp teknik pa w pou mete non sa nan fòma tit. Sa vle di premye lèt chak mo dwe majiskil, epi lòt yo miniskil. Epi afiche nouvo non an.\nEkzanp:\n\nAyiti se yon BEL PEYI"  ap vin bay "Ayiti Se Yon Bel Peyi \n'

# %%
def name_capitalized(name):
    words = name.split()
    capitalized_words = [word.capitalize() for word in words]
    return " ".join(capitalized_words)

name = input("Antre non ou: ")
capitalized_name = name_capitalized(name)
print(capitalized_name)
# Out:
# Jean Duckens Sannon
